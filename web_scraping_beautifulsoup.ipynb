# %% [markdown]
# ## Load libraries

# %%
import requests
import re
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## Load page

# %%
r = requests.get('https://keithgalli.github.io/web-scraping/webpage.html')

# Convert to beautifulsoup object

webpage = bs(r.content)

# Print out

print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %% [markdown]
# ## Beautifulsoup and scraping

# %%
links = webpage.select('.socials a')

actual_links = [link['href'] for link in links]
actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
# Scrape the table with pandas

'''
l = []
for tr = in table_rows:
  td = tr.find_all('td')
  row = [tr.text for tr in td]
  l.append(row)
pd.DataFrame(l, columns=['A', 'B',... 'Z'])

'''

import pandas as pd

table = webpage.select('table.hockey-stats')[0]
columns = table.find('thead').find_all('th')
column_names = [c.string for c in columns]
# column_names
# Out:
# ['S',
#  'Team',
#  'League',
#  'GP',
#  'G',
#  'A',
#  'TP',
#  'PIM',
#  '+/-',
#  '\xa0',
#  'POST',
#  'GP',
#  'G',
#  'A',
#  'TP',
#  'PIM',
#  '+/-']

# %%
table_rows = table.find('tbody').find_all('tr')

l = []
for tr in table_rows:
  td = tr.find_all('td')
  row = [str(tr.get_text()).strip() for tr in td]
  l.append(row)
# print(l)
df = pd.DataFrame(l, columns=column_names)
df
# Out:
#          S                        Team    League  GP  G   A  ... GP G A TP PIM +/-
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  ...
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1  ...
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  ...
# 3  2017-18                Did not play                       ...
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  ...
#
# [5 rows x 17 columns]

# %%
df.Team
# Out:
# 0    MIT (Mass. Inst. of Tech.)
# 1    MIT (Mass. Inst. of Tech.)
# 2    MIT (Mass. Inst. of Tech.)
# 3                  Did not play
# 4    MIT (Mass. Inst. of Tech.)
# Name: Team, dtype: object

# %%
df.loc[df['Team'] != 'Did not play']
# Out:
#          S                        Team    League  GP  G   A  ... GP G A TP PIM +/-
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  ...
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1  ...
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  ...
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  ...
#
# [4 rows x 17 columns]

# %%
facts = webpage.select('.fun-facts li')
facts_with_is = [fact.find(string=re.compile('is')) for fact in facts]
facts_with_is = [fact.find_parent().get_text() for fact in facts_with_is if fact]
facts_with_is
# Out:
# ['Middle name is Ronald',
#  'Dunkin Donuts coffee is better than Starbucks',
#  "A favorite book series of mine is Ender's Game",
#  'Current video game of choice is Rocket League',
#  "The band that I've seen the most times live is the Zac Brown Band"]

# %%
# Scrape images

images = webpage.select('.row img')

# %%
url = 'https://keithgalli.github.io/web-scraping/'
r = requests.get(url+'webpage.html')

# %%
image_url = images[0]['src']
full_url = url + image_url
print(full_url)
# Out:
# https://keithgalli.github.io/web-scraping/images/italy/lake_como.jpg

# %%
# Download images

img_data = requests.get(full_url).content
with open('image_sample.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
# Mystery challenges

files = webpage.select('.block li a') 
relative_files = [f['href'] for f in files]
relative_files
# Out:
# ['challenge/file_1.html',
#  'challenge/file_2.html',
#  'challenge/file_3.html',
#  'challenge/file_4.html',
#  'challenge/file_5.html',
#  'challenge/file_6.html',
#  'challenge/file_7.html',
#  'challenge/file_8.html',
#  'challenge/file_9.html',
#  'challenge/file_10.html']

# %%
url = 'https://keithgalli.github.io/web-scraping/'
# r = requests.get(url+'webpage.html')

# image_url = images[0]['src']
# full_url = url + image_url
# print(full_url)

for f in relative_files:
  full_url = url + f
  # print(full_url)
  page = requests.get(full_url)
  bs_page = bs(page.content)
  secret_word_ele = bs_page.find('p', attrs={'id': 'secret-word'})
  secret_word = secret_word_ele.string
  print(secret_word)
# Out:
# Make
# sure
# to
# smash
# that
# like
# button
# and
# subscribe
# !!!
